# %%
import user
import LSTM
import Senti
import matplotlib.pyplot as plt #visualize the data
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Choose one of the following companies for analysis (Ford, Nissan, Tesla):Ford
# Enter O for the opening stock value, C for the closing stock value, and M for the average value of two:M
# Enter the number of date (around 30-60) for training datasets for LSTM:50
# Enter the number of days (less than 200 days) to be analyzed from 03 May 2019:120
# /anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
test_1_day, test_x_days, predict, test_date_start, test_date_end, test_date = LSTM.stock_analyzer(user.company, user.CO, user.date, user.LSTM_date)
# Out:
# Train on 1087 samples, validate on 120 samples
# Epoch 1/20
# 1087/1087 [==============================] - 13s 12ms/step - loss: 0.0120 - val_loss: 0.0027
# Epoch 2/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0034 - val_loss: 9.8299e-04
# Epoch 3/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0024 - val_loss: 7.2996e-04
# Epoch 4/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0017 - val_loss: 7.0925e-04
# Epoch 5/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0016 - val_loss: 5.4579e-04
# Epoch 6/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0013 - val_loss: 4.6076e-04
# Epoch 7/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0011 - val_loss: 4.1317e-04
# Epoch 8/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0010 - val_loss: 6.4638e-04
# Epoch 9/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 8.9762e-04 - val_loss: 3.4048e-04
# Epoch 10/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 8.6649e-04 - val_loss: 2.7912e-04
# Epoch 11/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 7.7037e-04 - val_loss: 2.6628e-04
# Epoch 12/20
# 1087/1087 [==============================] - 12s 11ms/step - loss: 7.3450e-04 - val_loss: 3.8397e-04
# Epoch 13/20
# 1087/1087 [==============================] - 12s 11ms/step - loss: 6.3744e-04 - val_loss: 5.9458e-04
# Epoch 14/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 6.7768e-04 - val_loss: 3.5397e-04
# Epoch 15/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 6.1889e-04 - val_loss: 2.6903e-04
# Epoch 16/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 6.2421e-04 - val_loss: 2.1582e-04
# Epoch 17/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 5.6762e-04 - val_loss: 3.4517e-04
# Epoch 18/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 6.1399e-04 - val_loss: 2.2195e-04
# Epoch 19/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 5.4653e-04 - val_loss: 3.5195e-04
# Epoch 20/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 6.0573e-04 - val_loss: 2.0817e-04

# %%
sentiment = Senti.sentiment_analyzer(user.company, test_date_start, test_date_end, test_date)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
'''Data Visulization'''
fit = ((max(test_1_day)+max(predict)[0])/2)-((min(test_1_day)+min(predict)[0])/2)
fit_sentiment = []
for i in sentiment: #compressed the sentiment data to fit nicely with stock value
    fit_sentiment.append(i*fit)
    
figure = plt.figure (facecolor = "white")
ax = figure.add_subplot(1,1,1)
ax.plot (test_1_day, label = "original stock data")
ax.plot (predict,label = " predicted stock data")
ax.plot (sentiment,label = "sentiment score") #sentiment data compressed to nicely fit with stock data
ax.set_xlabel('total ' + str(user.date) + ' days (non-consecutive)')
ax.set_ylabel('nomralized stock & sentiment value')
ax.set_title(user.company + 
             ' ('+ str(test_date_start) + ' to ' + str(test_date_end) +')' + 
             '\n' + LSTM.title + ' Stock Values' + 
             '\n' + '& Sentiment Analysis' )
ax.legend()
plt.show()

# %%
fit
