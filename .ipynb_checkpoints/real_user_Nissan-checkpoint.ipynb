# %%
import user
import LSTM
import Senti
import matplotlib.pyplot as plt #visualize the data
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Choose one of the following companies for analysis (Ford, Nissan, Tesla):Nissan
# Enter O for the opening stock value, C for the closing stock value, and M for the average value of two:M
# Enter the number of date (around 30-60) for training datasets for LSTM:50
# Enter the number of days (less than 200 days) to be analyzed from 03 May 2019:120
# /anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
test_1_day, test_x_days, predict, test_date_start, test_date_end, test_date = LSTM.stock_analyzer(user.company, user.CO, user.date, user.LSTM_date)
# Out:
# Train on 1087 samples, validate on 120 samples
# Epoch 1/20
# 1087/1087 [==============================] - 13s 12ms/step - loss: 0.0184 - val_loss: 0.0112
# Epoch 2/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0066 - val_loss: 0.0107
# Epoch 3/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 4/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 5/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 6/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 7/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 8/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 9/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 10/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 11/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 12/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 13/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 14/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 15/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 16/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 17/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 18/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 19/20
# 1087/1087 [==============================] - 11s 10ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 20/20
# 1087/1087 [==============================] - 12s 11ms/step - loss: 0.0019 - val_loss: 0.0014

# %%
sentiment = Senti.sentiment_analyzer(user.company, test_date_start, test_date_end, test_date)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
'''Data Visulization'''
fit = ((max(test_1_day)+max(predict)[0])/2)-((min(test_1_day)+min(predict)[0])/2)
fit_sentiment = []
for i in sentiment: #compressed the sentiment data to fit nicely with stock value
    fit_sentiment.append(i*fit)
    
figure = plt.figure (facecolor = "white")
ax = figure.add_subplot(1,1,1)
ax.plot (test_1_day, label = "original stock data")
ax.plot (predict,label = " predicted stock data")
ax.plot (fit_sentiment,label = "sentiment score") #sentiment data compressed to nicely fit with stock data
ax.set_xlabel('total ' + str(user.date) + ' days (non-consecutive)')
ax.set_ylabel('nomralized stock & sentiment value')
ax.set_title(user.company + 
             ' ('+ str(test_date_start) + ' to ' + str(test_date_end) +')' + 
             '\n' + LSTM.title + ' Stock Values' + 
             '\n' + '& Sentiment Analysis' )
ax.legend()
plt.show()

# %%
fit
